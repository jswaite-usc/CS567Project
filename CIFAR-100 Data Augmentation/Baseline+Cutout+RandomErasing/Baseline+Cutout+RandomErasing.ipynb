# %%
#We will make a basic CNN model to classify CIFAR-100#
#We will use Keras from Tensorflow to build the model#

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
import numpy as np
import matplotlib.pyplot as plt
import datetime

#show the tensorflow version
print(tf.__version__)
# Out:
# 2.15.0

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10312816437638755432
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 21991653376
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 18167963559230654739
# physical_device_desc: "device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9"
# xla_global_id: 416903419
# ]
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#load the CIFAR-100 dataset & split into train and test sets
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

#Normalize pixel values from 1-255 to 0-1
x_train, x_test = x_train / 255.0, x_test / 255.0

#show the shape of the dataset
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
import copy
x_train_copy = copy.deepcopy(x_train)

# %% [markdown]
# ## Cutout Regularization

# %%
def apply_cutout(image, n_holes=1, length=10):
    h = image.shape[0] # height
    w = image.shape[1] # width

    mask = np.ones((h, w, 3), np.float32) # Create a mask to be applied to the regions that are cutout

    for _ in range(n_holes): # Number of regions to be cutout. Vary to check performance.
        y = np.random.randint(h) # Get a y coordinate in the image
        x = np.random.randint(w) # Get an x coordinate in the image

        y1 = np.clip(y - length // 2, 0, h) # top edge of the cutout region
        y2 = np.clip(y + length // 2, 0, h) # bottom edge of the cutout region
        x1 = np.clip(x - length // 2, 0, w) # left edge of the cutout region
        x2 = np.clip(x + length // 2, 0, w) # right edge of the cutout region

        mask[y1: y2, x1: x2, :] = 0 # Apply the mask (introduce black or 0 regions in the image)

    return image * mask # Return the image with the mask applied

# %%
x_train_cutout = np.array([apply_cutout(image) for image in x_train])

# %%
import matplotlib.pyplot as plt
print("Original images:")
for i in range(5):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i])
plt.show()
print("Images with cutout:")
for i in range(5):
    plt.subplot(330 + 1 + i)
    plt.imshow(apply_cutout(x_train[i]))
plt.show()
# Out:
# Original images:
# Images with cutout:

# %% [markdown]
# ## Random Erasing Regularization

# %%
def random_erasing(image, p=0.5, s=(0.02, 0.4), r=(0.3, 3.3)):
    if np.random.rand() > p: # Return the original image with some probability
        return image

    h, w, _ = image.shape # Get the shape of the image
    area = h * w # Caculate the area of the image

    while True:
        target_area = np.random.uniform(*s) * area
        aspect_ratio = np.random.uniform(*r)
        h_erasing = int(np.sqrt(target_area * aspect_ratio))
        w_erasing = int(np.sqrt(target_area / aspect_ratio))
        left = np.random.randint(0, w)
        top = np.random.randint(0, h)

        if left + w_erasing <= w and top + h_erasing <= h:
            break

    # top:top+h_erasing selects the rows of the image starting from index top up to top+h_erasing.
    # left:left+w_erasing selects the columns of the image starting from index left up to left+w_erasing.
    # : in the third dimension indicates that all color channels are selected.

    # Sets values in a 3d array of random numbers with shape(h_erasing, w_erasing, 3) - here 3 is the number of color channels.
    image[top:top+h_erasing, left:left+w_erasing, :] = np.random.rand(h_erasing, w_erasing, 3) * 255.0

    return image

# %%
x_train_random_erasing = np.array([random_erasing(image) for image in x_train_copy])

# %%
import matplotlib.pyplot as plt
print("Original images:")
for i in range(5):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i])
plt.show()
print("Images with cutout:")
for i in range(5):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train_random_erasing[i])
plt.show()
# Out:
# Original images:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Images with cutout:

# %% [markdown]
# ## Model

# %%
model = Sequential()

# Block 1
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 2
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 3
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 4
model.add(Flatten())
model.add(Dense(256, activation='relu'))

# Block 5
model.add(Dense(100, activation='softmax'))

# Print the model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_5 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_6 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_7 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 4, 4, 128)         147584
#
#  max_pooling2d_8 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_9 (MaxPoolin  (None, 1, 1, 128)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  dense_3 (Dense)             (None, 100)               25700
#
# =================================================================
# Total params: 456388 (1.74 MB)
# Trainable params: 456388 (1.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Cutout Model Training

# %%
#Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

#Train the model
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
history = model.fit(x_train_cutout, y_train, epochs=40, validation_data=(x_test, y_test), callbacks=[tensorboard_callback])
#save loss & validation loss every
train_loss = history.history['loss']
val_loss = history.history['val_loss']
# Out:
# Epoch 1/40
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1563/1563 [==============================] - 11s 6ms/step - loss: 4.1488 - accuracy: 0.0528 - val_loss: 3.7772 - val_accuracy: 0.1065
# Epoch 2/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 3.5522 - accuracy: 0.1440 - val_loss: 3.3299 - val_accuracy: 0.1839
# Epoch 3/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 3.1751 - accuracy: 0.2140 - val_loss: 3.0423 - val_accuracy: 0.2421
# Epoch 4/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.9157 - accuracy: 0.2653 - val_loss: 3.0076 - val_accuracy: 0.2514
# Epoch 5/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.7063 - accuracy: 0.3040 - val_loss: 2.7481 - val_accuracy: 0.3070
# Epoch 6/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.5180 - accuracy: 0.3438 - val_loss: 2.6712 - val_accuracy: 0.3202
# Epoch 7/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3697 - accuracy: 0.3731 - val_loss: 2.6346 - val_accuracy: 0.3374
# Epoch 8/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.2282 - accuracy: 0.4048 - val_loss: 2.6364 - val_accuracy: 0.3401
# Epoch 9/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.0986 - accuracy: 0.4319 - val_loss: 2.6394 - val_accuracy: 0.3475
# Epoch 10/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.9841 - accuracy: 0.4576 - val_loss: 2.6698 - val_accuracy: 0.3518
# Epoch 11/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.8817 - accuracy: 0.4795 - val_loss: 2.6865 - val_accuracy: 0.3522
# Epoch 12/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.7816 - accuracy: 0.5037 - val_loss: 2.7623 - val_accuracy: 0.3513
# Epoch 13/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.6905 - accuracy: 0.5223 - val_loss: 2.7626 - val_accuracy: 0.3596
# Epoch 14/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.5956 - accuracy: 0.5458 - val_loss: 2.9106 - val_accuracy: 0.3481
# Epoch 15/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.5130 - accuracy: 0.5649 - val_loss: 3.0057 - val_accuracy: 0.3465
# Epoch 16/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.4374 - accuracy: 0.5809 - val_loss: 3.0718 - val_accuracy: 0.3449
# Epoch 17/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3680 - accuracy: 0.6010 - val_loss: 3.2784 - val_accuracy: 0.3331
# Epoch 18/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.2965 - accuracy: 0.6180 - val_loss: 3.2967 - val_accuracy: 0.3430
# Epoch 19/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.2428 - accuracy: 0.6309 - val_loss: 3.4656 - val_accuracy: 0.3294
# Epoch 20/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.1860 - accuracy: 0.6465 - val_loss: 3.6119 - val_accuracy: 0.3374
# Epoch 21/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.1319 - accuracy: 0.6618 - val_loss: 3.9163 - val_accuracy: 0.3272
# Epoch 22/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0902 - accuracy: 0.6713 - val_loss: 3.8659 - val_accuracy: 0.3233
# Epoch 23/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0560 - accuracy: 0.6783 - val_loss: 3.8933 - val_accuracy: 0.3231
# Epoch 24/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0185 - accuracy: 0.6904 - val_loss: 4.0699 - val_accuracy: 0.3359
# Epoch 25/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9870 - accuracy: 0.6973 - val_loss: 4.2192 - val_accuracy: 0.3301
# Epoch 26/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9435 - accuracy: 0.7108 - val_loss: 4.2820 - val_accuracy: 0.3308
# Epoch 27/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9323 - accuracy: 0.7132 - val_loss: 4.3766 - val_accuracy: 0.3289
# Epoch 28/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9042 - accuracy: 0.7211 - val_loss: 4.4449 - val_accuracy: 0.3206
# Epoch 29/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8859 - accuracy: 0.7265 - val_loss: 4.5180 - val_accuracy: 0.3220
# Epoch 30/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8537 - accuracy: 0.7374 - val_loss: 4.6273 - val_accuracy: 0.3220
# Epoch 31/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8520 - accuracy: 0.7380 - val_loss: 4.6474 - val_accuracy: 0.3237
# Epoch 32/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8144 - accuracy: 0.7468 - val_loss: 4.9720 - val_accuracy: 0.3192
# Epoch 33/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7976 - accuracy: 0.7537 - val_loss: 5.0359 - val_accuracy: 0.3159
# Epoch 34/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7878 - accuracy: 0.7549 - val_loss: 5.0731 - val_accuracy: 0.3230
# Epoch 35/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7785 - accuracy: 0.7593 - val_loss: 5.1127 - val_accuracy: 0.3111
# Epoch 36/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7759 - accuracy: 0.7595 - val_loss: 5.1355 - val_accuracy: 0.3190
# Epoch 37/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7529 - accuracy: 0.7667 - val_loss: 5.5347 - val_accuracy: 0.3127
# Epoch 38/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7243 - accuracy: 0.7753 - val_loss: 5.6133 - val_accuracy: 0.3164
# Epoch 39/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7213 - accuracy: 0.7759 - val_loss: 5.4882 - val_accuracy: 0.3154
# Epoch 40/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7258 - accuracy: 0.7752 - val_loss: 5.5791 - val_accuracy: 0.3193

# %%
#Evaluate the model
test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 5.5791 - accuracy: 0.3193 - 637ms/epoch - 2ms/step
#
# Test accuracy: 0.31929999589920044

# %%
#Plot the training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# %%
#plot loss
plt.plot(train_loss, label='train loss')
plt.plot(val_loss, label = 'val loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
#legend
plt.legend(loc='upper left')
#show plot
plt.show()

# %%
#save the trained model (Parameters) so I can use it again without training again
model.save('cifar100_cnn_cutout.h5')
#save the trained model (Weights) so I can use it again without training again
model.save_weights('cifar100_cnn_weights_cutout.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
## CONFUSION MATRIX
# Load both fine and coarse labels
(x_train_fine, y_train_fine), (x_test_fine, y_test_fine) = cifar100.load_data(label_mode='fine')
(x_train_coarse, y_train_coarse), (x_test_coarse, y_test_coarse) = cifar100.load_data(label_mode='coarse')

# Establish a mapping from fine labels to coarse labels
class_to_superclass = {}
for fine, coarse in zip(y_train_fine.flatten(), y_train_coarse.flatten()):
    if fine not in class_to_superclass:
        class_to_superclass[fine] = coarse

# Optional: Check the mapping (for understanding/debugging)
print("Sample of class to superclass mapping:", {k: class_to_superclass[k] for k in list(class_to_superclass)[:5]})

# Predict the classes using the trained model
y_pred = model.predict(x_test_fine)
y_pred_classes = np.argmax(y_pred, axis=1)
y_pred_super = np.vectorize(class_to_superclass.get)(y_pred_classes)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Compute the confusion matrix for superclasses
cm_super = confusion_matrix(y_test_coarse, y_pred_super)

# Display the confusion matrix
plt.figure(figsize=(10, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_super)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix for Superclasses')
plt.xlabel('Predicted Superclass')
plt.ylabel('True Superclass')
plt.show()
# Out:
# Sample of class to superclass mapping: {19: 11, 29: 15, 0: 4, 11: 14, 1: 1}
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# ### Random Erasing Training

# %%
#Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

#Train the model
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
history = model.fit(x_train_random_erasing, y_train, epochs=40, validation_data=(x_test, y_test), callbacks=[tensorboard_callback])
#save loss & validation loss every
train_loss = history.history['loss']
val_loss = history.history['val_loss']
# Out:
# Epoch 1/40
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1563/1563 [==============================] - 11s 6ms/step - loss: 23.4986 - accuracy: 0.1735 - val_loss: 3.5853 - val_accuracy: 0.2900
# Epoch 2/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 3.0872 - accuracy: 0.2874 - val_loss: 3.7849 - val_accuracy: 0.3157
# Epoch 3/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.8921 - accuracy: 0.3339 - val_loss: 4.0581 - val_accuracy: 0.3238
# Epoch 4/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.8171 - accuracy: 0.3532 - val_loss: 4.0628 - val_accuracy: 0.3144
# Epoch 5/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.9345 - accuracy: 0.3280 - val_loss: 4.0342 - val_accuracy: 0.3094
# Epoch 6/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.8487 - accuracy: 0.3423 - val_loss: 4.2828 - val_accuracy: 0.3121
# Epoch 7/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.8880 - accuracy: 0.3326 - val_loss: 4.1883 - val_accuracy: 0.3033
# Epoch 8/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.9766 - accuracy: 0.3166 - val_loss: 4.0301 - val_accuracy: 0.3088
# Epoch 9/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.8959 - accuracy: 0.3348 - val_loss: 4.1141 - val_accuracy: 0.3037
# Epoch 10/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.8722 - accuracy: 0.3442 - val_loss: 4.1632 - val_accuracy: 0.3001
# Epoch 11/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.8218 - accuracy: 0.3498 - val_loss: 4.3061 - val_accuracy: 0.2979
# Epoch 12/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.8952 - accuracy: 0.3369 - val_loss: 4.4858 - val_accuracy: 0.3040
# Epoch 13/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.7490 - accuracy: 0.3694 - val_loss: 4.6370 - val_accuracy: 0.2985
# Epoch 14/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.8065 - accuracy: 0.3641 - val_loss: 4.7213 - val_accuracy: 0.2994
# Epoch 15/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.8162 - accuracy: 0.3629 - val_loss: 4.6200 - val_accuracy: 0.2890
# Epoch 16/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.7383 - accuracy: 0.3729 - val_loss: 5.0490 - val_accuracy: 0.3011
# Epoch 17/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.7018 - accuracy: 0.3844 - val_loss: 5.1534 - val_accuracy: 0.2974
# Epoch 18/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.8257 - accuracy: 0.3653 - val_loss: 5.0264 - val_accuracy: 0.3025
# Epoch 19/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6559 - accuracy: 0.3966 - val_loss: 5.4165 - val_accuracy: 0.2936
# Epoch 20/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6645 - accuracy: 0.3951 - val_loss: 5.4898 - val_accuracy: 0.3011
# Epoch 21/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6996 - accuracy: 0.3873 - val_loss: 5.4030 - val_accuracy: 0.2940
# Epoch 22/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6745 - accuracy: 0.3942 - val_loss: 5.6747 - val_accuracy: 0.3035
# Epoch 23/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6642 - accuracy: 0.3962 - val_loss: 5.6292 - val_accuracy: 0.2920
# Epoch 24/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6604 - accuracy: 0.3974 - val_loss: 5.8575 - val_accuracy: 0.3002
# Epoch 25/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6628 - accuracy: 0.3973 - val_loss: 5.7297 - val_accuracy: 0.2902
# Epoch 26/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6480 - accuracy: 0.4015 - val_loss: 5.7294 - val_accuracy: 0.2894
# Epoch 27/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.7049 - accuracy: 0.3907 - val_loss: 5.9125 - val_accuracy: 0.2994
# Epoch 28/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6537 - accuracy: 0.4034 - val_loss: 5.9654 - val_accuracy: 0.2849
# Epoch 29/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6215 - accuracy: 0.4107 - val_loss: 6.2299 - val_accuracy: 0.2907
# Epoch 30/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6651 - accuracy: 0.4061 - val_loss: 6.2190 - val_accuracy: 0.2942
# Epoch 31/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6221 - accuracy: 0.4089 - val_loss: 6.4546 - val_accuracy: 0.2910
# Epoch 32/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.7039 - accuracy: 0.3934 - val_loss: 6.2966 - val_accuracy: 0.2875
# Epoch 33/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.5990 - accuracy: 0.4181 - val_loss: 6.8796 - val_accuracy: 0.2782
# Epoch 34/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6239 - accuracy: 0.4090 - val_loss: 7.1620 - val_accuracy: 0.2810
# Epoch 35/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6140 - accuracy: 0.4139 - val_loss: 6.4956 - val_accuracy: 0.2953
# Epoch 36/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6328 - accuracy: 0.4097 - val_loss: 6.8090 - val_accuracy: 0.2886
# Epoch 37/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6123 - accuracy: 0.4151 - val_loss: 6.8354 - val_accuracy: 0.2840
# Epoch 38/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6092 - accuracy: 0.4153 - val_loss: 6.8124 - val_accuracy: 0.2806
# Epoch 39/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6208 - accuracy: 0.4120 - val_loss: 6.8377 - val_accuracy: 0.2811
# Epoch 40/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.6491 - accuracy: 0.4075 - val_loss: 6.9768 - val_accuracy: 0.2873

# %%
#Plot the training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# %%
#plot loss
plt.plot(train_loss, label='train loss')
plt.plot(val_loss, label = 'val loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
#legend
plt.legend(loc='upper left')
#show plot
plt.show()

# %%
## CONFUSION MATRIX
# Load both fine and coarse labels
(x_train_fine, y_train_fine), (x_test_fine, y_test_fine) = cifar100.load_data(label_mode='fine')
(x_train_coarse, y_train_coarse), (x_test_coarse, y_test_coarse) = cifar100.load_data(label_mode='coarse')

# Establish a mapping from fine labels to coarse labels
class_to_superclass = {}
for fine, coarse in zip(y_train_fine.flatten(), y_train_coarse.flatten()):
    if fine not in class_to_superclass:
        class_to_superclass[fine] = coarse

# Optional: Check the mapping (for understanding/debugging)
print("Sample of class to superclass mapping:", {k: class_to_superclass[k] for k in list(class_to_superclass)[:5]})

# Predict the classes using the trained model
y_pred = model.predict(x_test_fine)
y_pred_classes = np.argmax(y_pred, axis=1)
y_pred_super = np.vectorize(class_to_superclass.get)(y_pred_classes)

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Compute the confusion matrix for superclasses
cm_super = confusion_matrix(y_test_coarse, y_pred_super)

# Display the confusion matrix
plt.figure(figsize=(10, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_super)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix for Superclasses')
plt.xlabel('Predicted Superclass')
plt.ylabel('True Superclass')
plt.show()
# Out:
# Sample of class to superclass mapping: {19: 11, 29: 15, 0: 4, 11: 14, 1: 1}
# 313/313 [==============================] - 1s 2ms/step

# %%
#save the trained model (Parameters) so I can use it again without training again
model.save('cifar100_cnn_random_erasing.h5')
#save the trained model (Weights) so I can use it again without training again
model.save_weights('cifar100_cnn_weights_random_erasing.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
