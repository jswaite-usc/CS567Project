# %%
#We will make a basic CNN model to classify CIFAR-10#
#We will use Keras from Tensorflow to build the model#

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.applications import ResNet50
import numpy as np
import matplotlib.pyplot as plt
import datetime
import pandas as pd

#show the tensorflow version
print(tf.__version__)
# Out:
# 2.15.0

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4239577439873801335
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14626652160
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11374303713118950289
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#load the CIFAR-100 dataset & split into train and test sets
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

#Normalize pixel values from 1-255 to 0-1
x_train, x_test = x_train / 255.0, x_test / 255.0

#show the shape of the dataset
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
import copy
x_train_copy = copy.deepcopy(x_train)

# %% [markdown]
# ## Cutout Regularization

# %%
def apply_cutout(image, n_holes=1, length=10):
    h = image.shape[0] # height
    w = image.shape[1] # width

    mask = np.ones((h, w, 3), np.float32) # Create a mask to be applied to the regions that are cutout

    for _ in range(n_holes): # Number of regions to be cutout. Vary to check performance.
        y = np.random.randint(h) # Get a y coordinate in the image
        x = np.random.randint(w) # Get an x coordinate in the image

        y1 = np.clip(y - length // 2, 0, h) # top edge of the cutout region
        y2 = np.clip(y + length // 2, 0, h) # bottom edge of the cutout region
        x1 = np.clip(x - length // 2, 0, w) # left edge of the cutout region
        x2 = np.clip(x + length // 2, 0, w) # right edge of the cutout region

        mask[y1: y2, x1: x2, :] = 0 # Apply the mask (introduce black or 0 regions in the image)

    return image * mask # Return the image with the mask applied

# %%
x_train_cutout = np.array([apply_cutout(image) for image in x_train])

# %%
import matplotlib.pyplot as plt
print("Original images:")
for i in range(5):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i])
plt.show()
print("Images with cutout:")
for i in range(5):
    plt.subplot(330 + 1 + i)
    plt.imshow(apply_cutout(x_train[i]))
plt.show()
# Out:
# Original images:
# Images with cutout:

# %% [markdown]
# ## Random Erasing Regularization

# %%
def random_erasing(image, probability=0.5, sl=0.02, sh=0.2, r1=0.3, mean=[0, 0, 0]):
    if np.random.rand() < probability:
        img_h, img_w, img_c = image.shape
        area = img_h * img_w

        for _ in range(100):
            target_area = np.random.uniform(sl, sh) * area
            aspect_ratio = np.random.uniform(r1, 1 / r1)
            h = int(round(np.sqrt(target_area * aspect_ratio)))
            w = int(round(np.sqrt(target_area / aspect_ratio)))

            if w < img_w and h < img_h:
                x = np.random.randint(0, img_h - h)
                y = np.random.randint(0, img_w - w)
                image[x:x+h, y:y+w, :] = np.random.uniform(0, 1, size=(h, w, img_c))
                break

    return image

# %%
x_train_random_erasing = np.array([random_erasing(image) for image in x_train_copy])

# %%
import matplotlib.pyplot as plt
print("Original images:")
for i in range(5):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i])
plt.show()
print("Images with Random Erasing:")
for i in range(5):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train_random_erasing[i])
plt.show()
# Out:
# Original images:
# Images with Random Erasing:

# %% [markdown]
# ## Model

# %%
model = Sequential()

# Block 1
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 2
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 3
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 4
model.add(Flatten())
model.add(Dense(256, activation='relu'))

# Block 5
model.add(Dense(10, activation='softmax'))

# Print the model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_10 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_11 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 128)         73856
#
#  max_pooling2d_12 (MaxPooli  (None, 4, 4, 128)         0
#  ng2D)
#
#  conv2d_16 (Conv2D)          (None, 4, 4, 128)         147584
#
#  max_pooling2d_13 (MaxPooli  (None, 2, 2, 128)         0
#  ng2D)
#
#  conv2d_17 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_14 (MaxPooli  (None, 1, 1, 128)         0
#  ng2D)
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 256)               33024
#
#  dense_5 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 433258 (1.65 MB)
# Trainable params: 433258 (1.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Cutout Model Training

# %%
#Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

#Train the model
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
history = model.fit(x_train_cutout, y_train, epochs=40, validation_data=(x_test, y_test), callbacks=[tensorboard_callback])
#save loss & validation loss every
train_loss = history.history['loss']
val_loss = history.history['val_loss']
# Out:
# Epoch 1/40
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1563/1563 [==============================] - 11s 6ms/step - loss: 1.6109 - accuracy: 0.4016 - val_loss: 1.3141 - val_accuracy: 0.5162
# Epoch 2/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.1320 - accuracy: 0.5949 - val_loss: 0.9962 - val_accuracy: 0.6501
# Epoch 3/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9094 - accuracy: 0.6770 - val_loss: 0.8530 - val_accuracy: 0.7040
# Epoch 4/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7730 - accuracy: 0.7270 - val_loss: 0.8837 - val_accuracy: 0.6958
# Epoch 5/40
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.6788 - accuracy: 0.7619 - val_loss: 0.8061 - val_accuracy: 0.7344
# Epoch 6/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5982 - accuracy: 0.7898 - val_loss: 0.8136 - val_accuracy: 0.7346
# Epoch 7/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5317 - accuracy: 0.8119 - val_loss: 0.7575 - val_accuracy: 0.7521
# Epoch 8/40
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.4711 - accuracy: 0.8334 - val_loss: 0.8657 - val_accuracy: 0.7332
# Epoch 9/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4189 - accuracy: 0.8502 - val_loss: 0.8704 - val_accuracy: 0.7484
# Epoch 10/40
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.3703 - accuracy: 0.8673 - val_loss: 0.9177 - val_accuracy: 0.7490
# Epoch 11/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3296 - accuracy: 0.8841 - val_loss: 0.9472 - val_accuracy: 0.7375
# Epoch 12/40
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.2985 - accuracy: 0.8933 - val_loss: 0.9757 - val_accuracy: 0.7438
# Epoch 13/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2652 - accuracy: 0.9061 - val_loss: 1.0367 - val_accuracy: 0.7307
# Epoch 14/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2510 - accuracy: 0.9116 - val_loss: 1.0901 - val_accuracy: 0.7385
# Epoch 15/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2308 - accuracy: 0.9188 - val_loss: 1.1616 - val_accuracy: 0.7403
# Epoch 16/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2143 - accuracy: 0.9254 - val_loss: 1.1598 - val_accuracy: 0.7426
# Epoch 17/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2030 - accuracy: 0.9282 - val_loss: 1.2547 - val_accuracy: 0.7372
# Epoch 18/40
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.1964 - accuracy: 0.9329 - val_loss: 1.1656 - val_accuracy: 0.7485
# Epoch 19/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1784 - accuracy: 0.9388 - val_loss: 1.3463 - val_accuracy: 0.7403
# Epoch 20/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1729 - accuracy: 0.9405 - val_loss: 1.4413 - val_accuracy: 0.7404
# Epoch 21/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.1697 - accuracy: 0.9417 - val_loss: 1.3952 - val_accuracy: 0.7369
# Epoch 22/40
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.1586 - accuracy: 0.9462 - val_loss: 1.4892 - val_accuracy: 0.7380
# Epoch 23/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1516 - accuracy: 0.9482 - val_loss: 1.4029 - val_accuracy: 0.7409
# Epoch 24/40
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.1579 - accuracy: 0.9459 - val_loss: 1.5770 - val_accuracy: 0.7301
# Epoch 25/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.1517 - accuracy: 0.9478 - val_loss: 1.3724 - val_accuracy: 0.7446
# Epoch 26/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1421 - accuracy: 0.9524 - val_loss: 1.4328 - val_accuracy: 0.7392
# Epoch 27/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1401 - accuracy: 0.9538 - val_loss: 1.5025 - val_accuracy: 0.7401
# Epoch 28/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1349 - accuracy: 0.9528 - val_loss: 1.5387 - val_accuracy: 0.7365
# Epoch 29/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1264 - accuracy: 0.9575 - val_loss: 1.5260 - val_accuracy: 0.7417
# Epoch 30/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1273 - accuracy: 0.9584 - val_loss: 1.5818 - val_accuracy: 0.7374
# Epoch 31/40
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.1287 - accuracy: 0.9582 - val_loss: 1.5920 - val_accuracy: 0.7377
# Epoch 32/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1204 - accuracy: 0.9607 - val_loss: 1.5887 - val_accuracy: 0.7372
# Epoch 33/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1141 - accuracy: 0.9626 - val_loss: 1.6414 - val_accuracy: 0.7403
# Epoch 34/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1199 - accuracy: 0.9601 - val_loss: 1.5031 - val_accuracy: 0.7306
# Epoch 35/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1102 - accuracy: 0.9644 - val_loss: 1.6791 - val_accuracy: 0.7362
# Epoch 36/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1112 - accuracy: 0.9637 - val_loss: 1.7426 - val_accuracy: 0.7391
# Epoch 37/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1181 - accuracy: 0.9613 - val_loss: 1.5987 - val_accuracy: 0.7386
# Epoch 38/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1108 - accuracy: 0.9641 - val_loss: 1.6762 - val_accuracy: 0.7259
# Epoch 39/40
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.1048 - accuracy: 0.9663 - val_loss: 1.7180 - val_accuracy: 0.7447
# Epoch 40/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1136 - accuracy: 0.9624 - val_loss: 1.8099 - val_accuracy: 0.7404

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nTest accuracy {}'.format(test_acc))
# Prediction
y_pred = model.predict(x_test)

y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = y_test

# Compute the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Display the confusion matrix
plt.figure(figsize=(10, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title(f'Confusion Matrix for Cutout')
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.show()
# Out:
# 313/313 - 1s - loss: 1.8099 - accuracy: 0.7404 - 771ms/epoch - 2ms/step
#
# Test accuracy 0.7404000163078308
# 313/313 [==============================] - 1s 2ms/step

# %%
#Plot the training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# %%
#plot loss
plt.plot(train_loss, label='train loss')
plt.plot(val_loss, label = 'val loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
#legend
plt.legend(loc='upper left')
#show plot
plt.show()

# %%
#save the trained model (Parameters) so I can use it again without training again
model.save('cifar10_cnn_cutout.h5')
#save the trained model (Weights) so I can use it again without training again
model.save_weights('cifar10_cnn_weights_cutout.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ### Random Erasing Training

# %%
#Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

#Train the model
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
history = model.fit(x_train_random_erasing, y_train, epochs=40, validation_data=(x_test, y_test), callbacks=[tensorboard_callback])
#save loss & validation loss every
train_loss = history.history['loss']
val_loss = history.history['val_loss']
# Out:
# Epoch 1/40
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1563/1563 [==============================] - 11s 6ms/step - loss: 1.5754 - accuracy: 0.4116 - val_loss: 1.1543 - val_accuracy: 0.5782
# Epoch 2/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0712 - accuracy: 0.6148 - val_loss: 0.9136 - val_accuracy: 0.6769
# Epoch 3/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8777 - accuracy: 0.6890 - val_loss: 0.9154 - val_accuracy: 0.6790
# Epoch 4/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7554 - accuracy: 0.7338 - val_loss: 0.8214 - val_accuracy: 0.7184
# Epoch 5/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6638 - accuracy: 0.7654 - val_loss: 0.7735 - val_accuracy: 0.7394
# Epoch 6/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5856 - accuracy: 0.7957 - val_loss: 0.7496 - val_accuracy: 0.7468
# Epoch 7/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5167 - accuracy: 0.8179 - val_loss: 0.7938 - val_accuracy: 0.7460
# Epoch 8/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4605 - accuracy: 0.8368 - val_loss: 0.8408 - val_accuracy: 0.7423
# Epoch 9/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4077 - accuracy: 0.8570 - val_loss: 0.8064 - val_accuracy: 0.7478
# Epoch 10/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3538 - accuracy: 0.8749 - val_loss: 0.9035 - val_accuracy: 0.7440
# Epoch 11/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3216 - accuracy: 0.8866 - val_loss: 1.0756 - val_accuracy: 0.7196
# Epoch 12/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2919 - accuracy: 0.8971 - val_loss: 1.0606 - val_accuracy: 0.7317
# Epoch 13/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2616 - accuracy: 0.9074 - val_loss: 1.0214 - val_accuracy: 0.7490
# Epoch 14/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2447 - accuracy: 0.9128 - val_loss: 1.1331 - val_accuracy: 0.7403
# Epoch 15/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2251 - accuracy: 0.9220 - val_loss: 1.2610 - val_accuracy: 0.7470
# Epoch 16/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2054 - accuracy: 0.9280 - val_loss: 1.1797 - val_accuracy: 0.7361
# Epoch 17/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1981 - accuracy: 0.9310 - val_loss: 1.2451 - val_accuracy: 0.7394
# Epoch 18/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1848 - accuracy: 0.9352 - val_loss: 1.3180 - val_accuracy: 0.7382
# Epoch 19/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1702 - accuracy: 0.9409 - val_loss: 1.4082 - val_accuracy: 0.7413
# Epoch 20/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1704 - accuracy: 0.9409 - val_loss: 1.3953 - val_accuracy: 0.7293
# Epoch 21/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1671 - accuracy: 0.9422 - val_loss: 1.3410 - val_accuracy: 0.7384
# Epoch 22/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1553 - accuracy: 0.9468 - val_loss: 1.4343 - val_accuracy: 0.7389
# Epoch 23/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1531 - accuracy: 0.9482 - val_loss: 1.3595 - val_accuracy: 0.7368
# Epoch 24/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1379 - accuracy: 0.9537 - val_loss: 1.5262 - val_accuracy: 0.7367
# Epoch 25/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1407 - accuracy: 0.9529 - val_loss: 1.4635 - val_accuracy: 0.7383
# Epoch 26/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1352 - accuracy: 0.9542 - val_loss: 1.5358 - val_accuracy: 0.7382
# Epoch 27/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1382 - accuracy: 0.9538 - val_loss: 1.4593 - val_accuracy: 0.7392
# Epoch 28/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1287 - accuracy: 0.9573 - val_loss: 1.5345 - val_accuracy: 0.7294
# Epoch 29/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1310 - accuracy: 0.9561 - val_loss: 1.4767 - val_accuracy: 0.7387
# Epoch 30/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1291 - accuracy: 0.9574 - val_loss: 1.5458 - val_accuracy: 0.7307
# Epoch 31/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1234 - accuracy: 0.9593 - val_loss: 1.5815 - val_accuracy: 0.7412
# Epoch 32/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1213 - accuracy: 0.9600 - val_loss: 1.6073 - val_accuracy: 0.7383
# Epoch 33/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1199 - accuracy: 0.9623 - val_loss: 1.6087 - val_accuracy: 0.7356
# Epoch 34/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1208 - accuracy: 0.9604 - val_loss: 1.5882 - val_accuracy: 0.7382
# Epoch 35/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1166 - accuracy: 0.9617 - val_loss: 1.7355 - val_accuracy: 0.7308
# Epoch 36/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1124 - accuracy: 0.9631 - val_loss: 1.7339 - val_accuracy: 0.7308
# Epoch 37/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1130 - accuracy: 0.9637 - val_loss: 1.6696 - val_accuracy: 0.7365
# Epoch 38/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1109 - accuracy: 0.9642 - val_loss: 1.7932 - val_accuracy: 0.7329
# Epoch 39/40
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.1086 - accuracy: 0.9654 - val_loss: 1.5515 - val_accuracy: 0.7389
# Epoch 40/40
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1028 - accuracy: 0.9671 - val_loss: 1.6446 - val_accuracy: 0.7468

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nTest accuracy {}'.format(test_acc))
# Prediction
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = y_test

# Compute the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Display the confusion matrix
plt.figure(figsize=(10, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title(f'Confusion Matrix for Mixup')
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.show()
# Out:
# 313/313 - 1s - loss: 1.6446 - accuracy: 0.7468 - 761ms/epoch - 2ms/step
#
# Test accuracy 0.7468000054359436
# 313/313 [==============================] - 1s 2ms/step

# %%
#Plot the training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# %%
#plot loss
plt.plot(train_loss, label='train loss')
plt.plot(val_loss, label = 'val loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
#legend
plt.legend(loc='upper left')
#show plot
plt.show()

# %%
#save the trained model (Parameters) so I can use it again without training again
model.save('cifar10_cnn_random_erasing.h5')
#save the trained model (Weights) so I can use it again without training again
model.save_weights('cifar10_cnn_weights_random_erasing.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
