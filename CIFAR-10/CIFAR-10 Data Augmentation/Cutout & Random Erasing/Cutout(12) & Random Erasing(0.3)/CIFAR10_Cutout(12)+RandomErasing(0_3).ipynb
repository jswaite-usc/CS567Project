# %%
#We will make a basic CNN model to classify CIFAR-10#
#We will use Keras from Tensorflow to build the model#

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.metrics import SparseTopKCategoricalAccuracy
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.applications import ResNet50
import numpy as np
import matplotlib.pyplot as plt
import datetime
import pandas as pd

#show the tensorflow version
print(tf.__version__)
# Out:
# 2.15.0

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3308247346702894248
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14626652160
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9771231207790271491
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#load the CIFAR-100 dataset & split into train and test sets
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

#Normalize pixel values from 1-255 to 0-1
x_train, x_test = x_train / 255.0, x_test / 255.0

#show the shape of the dataset
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 15s 0us/step
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
import copy
x_train_copy = copy.deepcopy(x_train)

# %% [markdown]
# ## Cutout Regularization

# %%
def apply_cutout(image, n_holes=1, length=12):
    h = image.shape[0] # height
    w = image.shape[1] # width

    mask = np.ones((h, w, 3), np.float32) # Create a mask to be applied to the regions that are cutout

    for _ in range(n_holes): # Number of regions to be cutout. Vary to check performance.
        y = np.random.randint(h) # Get a y coordinate in the image
        x = np.random.randint(w) # Get an x coordinate in the image

        y1 = np.clip(y - length // 2, 0, h) # top edge of the cutout region
        y2 = np.clip(y + length // 2, 0, h) # bottom edge of the cutout region
        x1 = np.clip(x - length // 2, 0, w) # left edge of the cutout region
        x2 = np.clip(x + length // 2, 0, w) # right edge of the cutout region

        mask[y1: y2, x1: x2, :] = 0 # Apply the mask (introduce black or 0 regions in the image)

    return image * mask # Return the image with the mask applied

# %%
x_train_cutout = np.array([apply_cutout(image) for image in x_train])

# %%
import matplotlib.pyplot as plt
print("Original images:")
for i in range(5):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i])
plt.show()
print("Images with cutout:")
for i in range(5):
    plt.subplot(330 + 1 + i)
    plt.imshow(apply_cutout(x_train[i]))
plt.show()
# Out:
# Original images:
# Images with cutout:

# %% [markdown]
# ## Random Erasing Regularization

# %%
def random_erasing(image, probability=0.5, sl=0.02, sh=0.3, r1=0.3, mean=[0, 0, 0]):
    if np.random.rand() < probability:
        img_h, img_w, img_c = image.shape
        area = img_h * img_w

        for _ in range(100):
            target_area = np.random.uniform(sl, sh) * area
            aspect_ratio = np.random.uniform(r1, 1 / r1)
            h = int(round(np.sqrt(target_area * aspect_ratio)))
            w = int(round(np.sqrt(target_area / aspect_ratio)))

            if w < img_w and h < img_h:
                x = np.random.randint(0, img_h - h)
                y = np.random.randint(0, img_w - w)
                image[x:x+h, y:y+w, :] = np.random.uniform(0, 1, size=(h, w, img_c))
                break

    return image

# %%
x_train_random_erasing = np.array([random_erasing(image) for image in x_train_copy])

# %%
import matplotlib.pyplot as plt
print("Original images:")
for i in range(5):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i])
plt.show()
print("Images with Random Erasing:")
for i in range(5):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train_random_erasing[i])
plt.show()
# Out:
# Original images:
# Images with Random Erasing:

# %% [markdown]
# ## Model

# %%
model = Sequential()

# Block 1
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 2
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 3
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 4
model.add(Flatten())
model.add(Dense(256, activation='relu'))

# Block 5
model.add(Dense(10, activation='softmax'))

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 128)         147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 2, 2, 128)         147584
#
#  max_pooling2d_4 (MaxPoolin  (None, 1, 1, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 256)               33024
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 433258 (1.65 MB)
# Trainable params: 433258 (1.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Cutout Model Training

# %%
#Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy',SparseTopKCategoricalAccuracy(k=3)])

#Train the model
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
history = model.fit(x_train_cutout, y_train, epochs=20, validation_data=(x_test, y_test), callbacks=[tensorboard_callback])
#save loss & validation loss every
train_loss = history.history['loss']
val_loss = history.history['val_loss']
val_top3_accuracy = history.history['sparse_top_k_categorical_accuracy']
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1563/1563 [==============================] - 21s 10ms/step - loss: 1.8545 - accuracy: 0.2990 - sparse_top_k_categorical_accuracy: 0.6152 - val_loss: 1.4968 - val_accuracy: 0.4416 - val_sparse_top_k_categorical_accuracy: 0.7797
# Epoch 2/20
# 1563/1563 [==============================] - 15s 10ms/step - loss: 1.3972 - accuracy: 0.4883 - sparse_top_k_categorical_accuracy: 0.8143 - val_loss: 1.2366 - val_accuracy: 0.5539 - val_sparse_top_k_categorical_accuracy: 0.8600
# Epoch 3/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.1900 - accuracy: 0.5684 - sparse_top_k_categorical_accuracy: 0.8625 - val_loss: 1.1085 - val_accuracy: 0.6015 - val_sparse_top_k_categorical_accuracy: 0.8804
# Epoch 4/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.0452 - accuracy: 0.6264 - sparse_top_k_categorical_accuracy: 0.8924 - val_loss: 0.9855 - val_accuracy: 0.6522 - val_sparse_top_k_categorical_accuracy: 0.9004
# Epoch 5/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.9495 - accuracy: 0.6615 - sparse_top_k_categorical_accuracy: 0.9066 - val_loss: 0.9267 - val_accuracy: 0.6687 - val_sparse_top_k_categorical_accuracy: 0.9100
# Epoch 6/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8712 - accuracy: 0.6872 - sparse_top_k_categorical_accuracy: 0.9220 - val_loss: 0.9005 - val_accuracy: 0.6844 - val_sparse_top_k_categorical_accuracy: 0.9171
# Epoch 7/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.8051 - accuracy: 0.7130 - sparse_top_k_categorical_accuracy: 0.9309 - val_loss: 0.8779 - val_accuracy: 0.6955 - val_sparse_top_k_categorical_accuracy: 0.9199
# Epoch 8/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7534 - accuracy: 0.7316 - sparse_top_k_categorical_accuracy: 0.9370 - val_loss: 0.8987 - val_accuracy: 0.6902 - val_sparse_top_k_categorical_accuracy: 0.9220
# Epoch 9/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.6993 - accuracy: 0.7503 - sparse_top_k_categorical_accuracy: 0.9452 - val_loss: 0.9117 - val_accuracy: 0.6954 - val_sparse_top_k_categorical_accuracy: 0.9173
# Epoch 10/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.6536 - accuracy: 0.7674 - sparse_top_k_categorical_accuracy: 0.9509 - val_loss: 0.8823 - val_accuracy: 0.7049 - val_sparse_top_k_categorical_accuracy: 0.9222
# Epoch 11/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6111 - accuracy: 0.7783 - sparse_top_k_categorical_accuracy: 0.9568 - val_loss: 0.8816 - val_accuracy: 0.7063 - val_sparse_top_k_categorical_accuracy: 0.9188
# Epoch 12/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.5661 - accuracy: 0.7977 - sparse_top_k_categorical_accuracy: 0.9609 - val_loss: 0.9494 - val_accuracy: 0.7056 - val_sparse_top_k_categorical_accuracy: 0.9213
# Epoch 13/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5273 - accuracy: 0.8113 - sparse_top_k_categorical_accuracy: 0.9672 - val_loss: 1.0078 - val_accuracy: 0.6924 - val_sparse_top_k_categorical_accuracy: 0.9144
# Epoch 14/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4963 - accuracy: 0.8214 - sparse_top_k_categorical_accuracy: 0.9709 - val_loss: 1.0447 - val_accuracy: 0.7019 - val_sparse_top_k_categorical_accuracy: 0.9177
# Epoch 15/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4616 - accuracy: 0.8340 - sparse_top_k_categorical_accuracy: 0.9741 - val_loss: 1.0237 - val_accuracy: 0.7062 - val_sparse_top_k_categorical_accuracy: 0.9180
# Epoch 16/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4277 - accuracy: 0.8459 - sparse_top_k_categorical_accuracy: 0.9776 - val_loss: 1.1038 - val_accuracy: 0.7035 - val_sparse_top_k_categorical_accuracy: 0.9147
# Epoch 17/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3921 - accuracy: 0.8587 - sparse_top_k_categorical_accuracy: 0.9803 - val_loss: 1.1244 - val_accuracy: 0.6991 - val_sparse_top_k_categorical_accuracy: 0.9134
# Epoch 18/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.3697 - accuracy: 0.8688 - sparse_top_k_categorical_accuracy: 0.9822 - val_loss: 1.2092 - val_accuracy: 0.7020 - val_sparse_top_k_categorical_accuracy: 0.9157
# Epoch 19/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.3592 - accuracy: 0.8705 - sparse_top_k_categorical_accuracy: 0.9838 - val_loss: 1.2169 - val_accuracy: 0.6987 - val_sparse_top_k_categorical_accuracy: 0.9128
# Epoch 20/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3309 - accuracy: 0.8807 - sparse_top_k_categorical_accuracy: 0.9866 - val_loss: 1.3002 - val_accuracy: 0.7002 - val_sparse_top_k_categorical_accuracy: 0.9130

# %%
test_loss, test_acc, top3 = model.evaluate(x_test, y_test, verbose=2)
print('\nTest accuracy {}'.format(test_acc))
print('\nTop 3 accuracy {}'.format(top3))
# Prediction
y_pred = model.predict(x_test)

y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = y_test

# Compute the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Display the confusion matrix
plt.figure(figsize=(10, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title(f'Confusion Matrix for Cutout')
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.show()
# Out:
# 313/313 - 1s - loss: 1.3002 - accuracy: 0.7002 - sparse_top_k_categorical_accuracy: 0.9130 - 716ms/epoch - 2ms/step
#
# Test accuracy 0.7002000212669373
#
# Top 3 accuracy 0.9129999876022339
# 313/313 [==============================] - 1s 2ms/step

# %%
#Plot the training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.plot(val_top3_accuracy, label = 'val top 3 accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# %%
#plot loss
plt.plot(train_loss, label='train loss')
plt.plot(val_loss, label = 'val loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
#legend
plt.legend(loc='upper left')
#show plot
plt.show()

# %%
#save the trained model (Parameters) so I can use it again without training again
model.save('cifar10_cnn_cutout(12).h5')
#save the trained model (Weights) so I can use it again without training again
model.save_weights('cifar10_cnn_weights_cutout(12).h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ### Random Erasing Training

# %%
model = Sequential()

# Block 1
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 2
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 3
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Block 4
model.add(Flatten())
model.add(Dense(256, activation='relu'))

# Block 5
model.add(Dense(10, activation='softmax'))

# Print the model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_5 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_6 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_7 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 4, 4, 128)         147584
#
#  max_pooling2d_8 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 2, 2, 128)         147584
#
#  max_pooling2d_9 (MaxPoolin  (None, 1, 1, 128)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  dense_3 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 433258 (1.65 MB)
# Trainable params: 433258 (1.65 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy',SparseTopKCategoricalAccuracy(k=3)])

#Train the model
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
history = model.fit(x_train_random_erasing, y_train, epochs=20, validation_data=(x_test, y_test), callbacks=[tensorboard_callback])
#save loss & validation loss every
train_loss = history.history['loss']
val_loss = history.history['val_loss']
val_top3_accuracy = history.history['sparse_top_k_categorical_accuracy']
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 1563/1563 [==============================] - 14s 7ms/step - loss: 1.6268 - accuracy: 0.3933 - sparse_top_k_categorical_accuracy: 0.7167 - val_loss: 1.2016 - val_accuracy: 0.5485 - val_sparse_top_k_categorical_accuracy: 0.8584
# Epoch 2/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.1467 - accuracy: 0.5856 - sparse_top_k_categorical_accuracy: 0.8686 - val_loss: 1.0233 - val_accuracy: 0.6386 - val_sparse_top_k_categorical_accuracy: 0.8912
# Epoch 3/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.9406 - accuracy: 0.6662 - sparse_top_k_categorical_accuracy: 0.9071 - val_loss: 0.8571 - val_accuracy: 0.6993 - val_sparse_top_k_categorical_accuracy: 0.9184
# Epoch 4/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8107 - accuracy: 0.7137 - sparse_top_k_categorical_accuracy: 0.9281 - val_loss: 0.8036 - val_accuracy: 0.7209 - val_sparse_top_k_categorical_accuracy: 0.9266
# Epoch 5/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.7245 - accuracy: 0.7450 - sparse_top_k_categorical_accuracy: 0.9399 - val_loss: 0.8049 - val_accuracy: 0.7216 - val_sparse_top_k_categorical_accuracy: 0.9298
# Epoch 6/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.6307 - accuracy: 0.7782 - sparse_top_k_categorical_accuracy: 0.9519 - val_loss: 0.7776 - val_accuracy: 0.7410 - val_sparse_top_k_categorical_accuracy: 0.9354
# Epoch 7/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.5646 - accuracy: 0.7998 - sparse_top_k_categorical_accuracy: 0.9602 - val_loss: 0.8060 - val_accuracy: 0.7480 - val_sparse_top_k_categorical_accuracy: 0.9359
# Epoch 8/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.5058 - accuracy: 0.8202 - sparse_top_k_categorical_accuracy: 0.9691 - val_loss: 0.8280 - val_accuracy: 0.7386 - val_sparse_top_k_categorical_accuracy: 0.9310
# Epoch 9/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4476 - accuracy: 0.8404 - sparse_top_k_categorical_accuracy: 0.9747 - val_loss: 0.8530 - val_accuracy: 0.7395 - val_sparse_top_k_categorical_accuracy: 0.9307
# Epoch 10/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4011 - accuracy: 0.8582 - sparse_top_k_categorical_accuracy: 0.9784 - val_loss: 0.9092 - val_accuracy: 0.7311 - val_sparse_top_k_categorical_accuracy: 0.9324
# Epoch 11/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3621 - accuracy: 0.8714 - sparse_top_k_categorical_accuracy: 0.9831 - val_loss: 0.9844 - val_accuracy: 0.7366 - val_sparse_top_k_categorical_accuracy: 0.9316
# Epoch 12/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3237 - accuracy: 0.8845 - sparse_top_k_categorical_accuracy: 0.9870 - val_loss: 1.0086 - val_accuracy: 0.7442 - val_sparse_top_k_categorical_accuracy: 0.9279
# Epoch 13/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2997 - accuracy: 0.8925 - sparse_top_k_categorical_accuracy: 0.9888 - val_loss: 1.0432 - val_accuracy: 0.7419 - val_sparse_top_k_categorical_accuracy: 0.9323
# Epoch 14/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2646 - accuracy: 0.9066 - sparse_top_k_categorical_accuracy: 0.9904 - val_loss: 1.1092 - val_accuracy: 0.7273 - val_sparse_top_k_categorical_accuracy: 0.9231
# Epoch 15/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2476 - accuracy: 0.9119 - sparse_top_k_categorical_accuracy: 0.9921 - val_loss: 1.2992 - val_accuracy: 0.7200 - val_sparse_top_k_categorical_accuracy: 0.9254
# Epoch 16/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2356 - accuracy: 0.9165 - sparse_top_k_categorical_accuracy: 0.9932 - val_loss: 1.2420 - val_accuracy: 0.7391 - val_sparse_top_k_categorical_accuracy: 0.9279
# Epoch 17/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2118 - accuracy: 0.9256 - sparse_top_k_categorical_accuracy: 0.9937 - val_loss: 1.2709 - val_accuracy: 0.7310 - val_sparse_top_k_categorical_accuracy: 0.9248
# Epoch 18/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2043 - accuracy: 0.9281 - sparse_top_k_categorical_accuracy: 0.9945 - val_loss: 1.2474 - val_accuracy: 0.7340 - val_sparse_top_k_categorical_accuracy: 0.9296
# Epoch 19/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.1867 - accuracy: 0.9361 - sparse_top_k_categorical_accuracy: 0.9955 - val_loss: 1.2984 - val_accuracy: 0.7328 - val_sparse_top_k_categorical_accuracy: 0.9246
# Epoch 20/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1850 - accuracy: 0.9353 - sparse_top_k_categorical_accuracy: 0.9959 - val_loss: 1.4019 - val_accuracy: 0.7300 - val_sparse_top_k_categorical_accuracy: 0.9242

# %%
test_loss, test_acc, top3 = model.evaluate(x_test, y_test, verbose=2)
print('\nTest accuracy {}'.format(test_acc))
print('\nTop 3 accuracy {}'.format(top3))
# Prediction
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = y_test

# Compute the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Display the confusion matrix
plt.figure(figsize=(10, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title(f'Confusion Matrix for Mixup')
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.show()
# Out:
# 313/313 - 1s - loss: 1.4019 - accuracy: 0.7300 - sparse_top_k_categorical_accuracy: 0.9242 - 1s/epoch - 4ms/step
#
# Test accuracy 0.7300000190734863
#
# Top 3 accuracy 0.9241999983787537
# 313/313 [==============================] - 1s 2ms/step

# %%
#Plot the training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.plot(val_top3_accuracy, label = 'val top 3 accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

# %%
#plot loss
plt.plot(train_loss, label='train loss')
plt.plot(val_loss, label = 'val loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
#legend
plt.legend(loc='upper left')
#show plot
plt.show()

# %%
#save the trained model (Parameters) so I can use it again without training again
model.save('cifar10_cnn_random_erasing(0.3).h5')
#save the trained model (Weights) so I can use it again without training again
model.save_weights('cifar10_cnn_weights_random_erasing(0.3).h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
